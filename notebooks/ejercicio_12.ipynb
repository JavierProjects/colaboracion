# %% [markdown]
# <span style="color: blue;">Psicología</span>. Según encuestas realizadas, uno de cada cuatro adolescentes estaría dispuesto a someterse a una cirugía plástica para parecerse a alguna personalidad como David Beckham, Usher o Justin Bieber. Supón que 15 personas asisten a una reunión,
#
# a) ¿Cuál es la probabilidad de que al menos 10 de ellas quisieran parecerse a alguna personalidad?
#
# b) ¿Cuál es la probabilidad de que exactamente cinco quisieran practicarse una cirugía plástica?
#
# Sea:
#
# $$X=\mbox{numero de jovenes dispuestos a operarse}$$
#
# como cada 1 de cada 4 la probabillidad es de 0.25
#
# $$X∼\mbox{Binomial}(n=15,p=0.25)$$

# %% [markdown]
# ## a) Probabilidad de que al menos 10 de ellas quisieran parecerse a alguna personalidad
#
# La función de probabilidad es:
#
# $$P(X=x)=\binom{15}{x}(0.25)^x(0.75)^{15-x} \quad \mbox{con} \quad x=10,11,12,\dots,15$$
#
# Tabla de distribucion de probabilidad con valores aproximadados:

# %% [markdown]
# <table style="border-collapse: collapse; width: 420px; text-align: center;">
#   <thead>
#     <tr>
#       <th style="border: 1px solid #000; padding: 10px; width: 160px;">x</th>
#       <th style="border: 1px solid #000; padding: 10px; width: 260px;">P(X=x)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="border: 1px solid #000; padding: 8px;">10</td>
#       <td style="border: 1px solid #000; padding: 8px;">0.0006798</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #000; padding: 8px;">11</td>
#       <td style="border: 1px solid #000; padding: 8px;">0.0001030</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #000; padding: 8px;">12</td>
#       <td style="border: 1px solid #000; padding: 8px;">0.0000114</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #000; padding: 8px;">13</td>
#       <td style="border: 1px solid #000; padding: 8px;">0.0000009</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #000; padding: 8px;">14</td>
#       <td style="border: 1px solid #000; padding: 8px;">0.00000004</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #000; padding: 8px;">15</td>
#       <td style="border: 1px solid #000; padding: 8px;">0.000000001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Sumando estos valores extremadamente pequeños:
#
# $$P(X \ge 10) \approx 0.0006798 + 0.0001030 + 0.0000114 + 0.0000009 \approx 0.000795$$
#
# Por lo tanto:
#
# $$P(X \ge 10) \approx 0.000795$$
#
# Es decir, aproximadamente:
#
# $$0.0795\%$$

# %% [markdown]
# ## b) Probabilidad de que exactamente cinco quisieran practicarse una cirugía plástica
#
# Calculamos para $k = 5$:$$P(X = 5) = \binom{15}{5} \cdot (0.25)^5 \cdot (0.75)^{10}$$
#
# Coeficiente binomial: $\binom{15}{5} = \frac{15!}{5! \cdot 10!} = 3003$Potencias:$$(0.25)^5 = 0.00097656$$$$(0.75)^{10} \approx 0.0563135$$
#
# Multiplicación:$$P(X = 5) \approx 3003 \cdot 0.00097656 \cdot 0.0563135 \approx 0.1651$$Respuesta
#
# b): La probabilidad de que exactamente 5 personas en la reunión quieran someterse a la cirugía es de aproximadamente $16.51\%$ (o $0.1651$).
